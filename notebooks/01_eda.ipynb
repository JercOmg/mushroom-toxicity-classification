# %% [markdown]
# # 01 - Análisis Exploratorio de Datos (EDA)
# ## Clasificación de Toxicidad de Hongos
#
# Este cuaderno realiza el análisis exploratorio, distribuciones de variables y correlaciones del conjunto de datos.

# %%
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Añadir src al path para importar módulos
sys.path.append(str(Path.cwd().parent))
from src.data_loader import load_raw_data, NUMERIC_COLUMNS, TARGET_COLUMN

# %%
# Cargar datos crudos
df = load_raw_data()
print(f"Dimensiones del dataset: {df.shape}")
df.head()

# %%
# Distribución de la variable objetivo (class)
print(df[TARGET_COLUMN].value_counts(normalize=True))
sns.countplot(data=df, x=TARGET_COLUMN)
plt.title("Distribución de la Clase (p=venenoso, e=comestible)")
plt.show()

# %%
# Resumen estadístico de variables numéricas
df[NUMERIC_COLUMNS].describe().T
